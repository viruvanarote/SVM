# %%
# SVM Classification
import pandas as pd
import numpy as np

from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report


from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

# %%
SVM_salary_test = pd.read_csv("C:\Games\Bhag Milkha Bhag 2013 Hindi MC DVDScr Xvid AC3 IcTv\Desktop\CSV\SalaryData_Test(1).csv")
SVM_salary_train = pd.read_csv("C:\Games\Bhag Milkha Bhag 2013 Hindi MC DVDScr Xvid AC3 IcTv\Desktop\CSV\SalaryData_Train(1).csv")

# %%
SVM_salary_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
SVM_salary_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
SVM_salary_train.shape
# Out:
# (30161, 14)

# %%
SVM_salary_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
SVM_salary_train1=SVM_salary_train.drop('educationno',axis=1)

# %%
SVM_salary_train1.columns
# Out:
# Index(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
str_col=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
for i in str_col:
    SVM_salary_train1[i]=labelencoder.fit_transform(SVM_salary_train1[i])

# %%
SVM_salary_train1.head(20)
# Out:
#     age  workclass  education  maritalstatus  occupation  relationship  race  \
# 0    39          5          9              4           0             1     4
# 1    50          4          9              2           3             0     4
# 2    38          2         11              0           5             1     4
# 3    53          2          1              2           5             0     2
# 4    28          2          9              2           9             5     2
# 5    37          2         12              2           3             5     4
# 6    49          2          6              3           7             1     2
# 7    52          4         11              2           3             0     4
# 8    31          2         12              4           9             1     4
# 9    42          2          9              2           3             0     4
# 10   37          2         15              2           3             0     2
# ...

# %%
SVM_salary_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
SVM_salary_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
SVM_salary_test1=SVM_salary_test.drop('educationno',axis=1)

# %%
SVM_salary_test1.head()
# Out:
#    age   workclass      education        maritalstatus          occupation  \
# 0   25     Private           11th        Never-married   Machine-op-inspct
# 1   38     Private        HS-grad   Married-civ-spouse     Farming-fishing
# 2   28   Local-gov     Assoc-acdm   Married-civ-spouse     Protective-serv
# 3   44     Private   Some-college   Married-civ-spouse   Machine-op-inspct
# 4   34     Private           10th        Never-married       Other-service
#
#      relationship    race    sex  capitalgain  capitalloss  hoursperweek  \
# 0       Own-child   Black   Male            0            0            40
# 1         Husband   White   Male            0            0            50
# 2         Husband   White   Male            0            0            40
# 3         Husband   Black   Male         7688            0            40
# 4   Not-in-family   White   Male            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# ...

# %%
SVM_salary_test1.columns
# Out:
# Index(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
str_col1=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
for i in str_col1:
    SVM_salary_test1[i]=labelencoder.fit_transform(SVM_salary_test1[i])

# %%
SVM_salary_test1.head()
# Out:
#    age  workclass  education  maritalstatus  occupation  relationship  race  \
# 0   25          2          1              4           6             3     2
# 1   38          2         11              2           4             0     4
# 2   28          1          7              2          10             0     4
# 3   44          2         15              2           6             0     2
# 4   34          2          0              4           7             1     4
#
#    sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0    1            0            0            40      37   <=50K
# 1    1            0            0            50      37   <=50K
# 2    1            0            0            40      37    >50K
# 3    1         7688            0            40      37    >50K
# 4    1            0            0            30      37   <=50K

# %%
SVM_salary_train1.shape
# Out:
# (30161, 13)

# %%
SVM_salary_test1.shape
# Out:
# (15060, 13)

# %%
X = SVM_salary_train1.iloc[: ,0:12]

# %%
X
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       39          5          9              4           0             1
# 1       50          4          9              2           3             0
# 2       38          2         11              0           5             1
# 3       53          2          1              2           5             0
# 4       28          2          9              2           9             5
# ...    ...        ...        ...            ...         ...           ...
# 30156   27          2          7              2          12             5
# 30157   40          2         11              2           6             0
# 30158   58          2         11              6           0             4
# 30159   22          2         11              4           0             3
# 30160   52          3         11              2           3             5
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
Y = SVM_salary_train1.iloc[: , 12]

# %%
Y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
Xtest = SVM_salary_test1.iloc[ : ,0:12]

# %%
Ytest = SVM_salary_test1.iloc[ : ,12]

# %%
clf = SVC(C= 15, gamma = 50)
clf.fit(X , Y)
# Out:
# SVC(C=15, gamma=50)

# %%
y_pred = clf.predict(Xtest)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(Ytest, y_pred)
print('\n')
print(classification_report(Ytest,y_pred))
# Out:
# Accuracy = 76.22177954847278
#
#
#               precision    recall  f1-score   support
#
#        <=50K       0.77      0.98      0.86     11360
#         >50K       0.61      0.09      0.16      3700
#
#     accuracy                           0.76     15060
#    macro avg       0.69      0.54      0.51     15060
# weighted avg       0.73      0.76      0.69     15060

# %%
clf = SVC()
clf.fit(X , Y)
# Out:
# SVC()

# %%
y_pred = clf.predict(Xtest)

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(Ytest, y_pred)
print('\n')
print(classification_report(Ytest,y_pred))
# Out:
# Accuracy = 79.64143426294821
#
#
#               precision    recall  f1-score   support
#
#        <=50K       0.80      0.97      0.88     11360
#         >50K       0.73      0.27      0.39      3700
#
#     accuracy                           0.80     15060
#    macro avg       0.77      0.62      0.64     15060
# weighted avg       0.79      0.80      0.76     15060

# %%
clf = SVC(C= 15, gamma = 100,kernel='rbf')
clf.fit(X , Y)
# Out:
# SVC(C=15, gamma=100)

# %%
y_pred = clf.predict(Xtest)

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(Ytest, y_pred)
print('\n')
print(classification_report(Ytest,y_pred))
# Out:
# Accuracy = 76.22177954847278
#
#
#               precision    recall  f1-score   support
#
#        <=50K       0.77      0.98      0.86     11360
#         >50K       0.61      0.09      0.16      3700
#
#     accuracy                           0.76     15060
#    macro avg       0.69      0.54      0.51     15060
# weighted avg       0.73      0.76      0.69     15060

# %%
clf = SVC()
#param_grid = [{'kernel':['poly'],'gamma':[100,5,15,0.5],'C':[19,14,13,12,11,10,0.1,0.001] }]
param_grid = [{'kernel':['rbf','poly'],'gamma':[100,5,15,0.5],'C':[12,11,10,0.1,0.001] }]
gsv = GridSearchCV(clf,param_grid,cv=10)
gsv.fit(X , Y)
